# %%
data = {
    "Day": [1, 30, 60, 90, 120, 150, 180, 210, 240, 270],
    "Value": [0.37, 0.49, 0.5, 0.52, 0.63, 1.02, 1.5, 2.7, 3.9, 6.3]
}
import pandas as pd
import seaborn as sns

# %%
df = pd.DataFrame(data)

# %%
sns.scatterplot(data=df, x="Day", y="Value")
# Out:
# <AxesSubplot:xlabel='Day', ylabel='Value'>
